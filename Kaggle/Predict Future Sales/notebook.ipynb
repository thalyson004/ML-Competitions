# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns 
from googletrans import Translator

from sklearn.model_selection import train_test_split

# %matplotlib inline
mpl.rcParams["figure.dpi"] = 300

# %%
# Read data
df_items_category = pd.read_csv("data/item_categories.csv")
df_items = pd.read_csv("data/items.csv")
df_shops = pd.read_csv("data/shops.csv")

df_sales_train = pd.read_csv("data/sales_train.csv")

df_sample_submission = pd.read_csv("data/sample_submission.csv")
df_test = pd.read_csv("data/test.csv")

# %%
df_small =  train_test_split(df_sales_train, train_size= 0.95)[1]

# %%
df_small.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day'],
#       dtype='object')

# %%
df_small.sort_values(by='date_block_num')
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1049     13.01.2013               0       25     5070      1590.0
# 44263    31.01.2013               0        1     4267       589.0
# 60788    07.01.2013               0       31     6023       299.0
# 82734    07.01.2013               0       29    14776       399.0
# 64673    30.01.2013               0       30     2574       399.0
# ...             ...             ...      ...      ...         ...
# 2917324  07.10.2015              33        4     6506      1499.0
# 2882374  24.10.2015              33       45    13634       999.0
# 2933341  17.10.2015              33       25    14803       799.0
# 2893859  28.10.2015              33       35     7337       299.0
# 2907678  30.10.2015              33       15    10043       999.0
#
#          item_cnt_day
# 1049              1.0
# 44263             1.0
# 60788             1.0
# 82734             1.0
# 64673             1.0
# ...               ...
# ...

# %%
sns.catplot(data=df_small, x="date_block_num", y="item_cnt_day", height=5, aspect=2)

# %%
g = sns.catplot(
    data=df_small.groupby('date_block_num', as_index=False).sum(), 
    x='date_block_num', 
    y='item_cnt_day',
    kind="bar",
    height=5,
    aspect=2,
)
g.set_axis_labels("Months", "Sold items")
plt.title('Sold items by month')
# Out:
# Text(0.5, 1.0, 'Sold items by month')

# %%
sns.catplot(
    data=df_small.groupby('date_block_num', as_index=False).sum(), 
    x='date_block_num', 
    y='item_price',
    kind="bar",
    height=5,
    aspect=2
)
